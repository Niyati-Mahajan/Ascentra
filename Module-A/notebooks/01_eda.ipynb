# %%
import pandas as pd
df=pd.read_csv("../data/data.csv",sep=";")
print(df.shape)
print(df.head())
print(df.info())
print(df.isnull().sum())
# Out:
# (4424, 37)
#    Marital status  Application mode  Application order  Course  \
# 0               1                17                  5     171
# 1               1                15                  1    9254
# 2               1                 1                  5    9070
# 3               1                17                  2    9773
# 4               2                39                  1    8014
#
#    Daytime/evening attendance\t  Previous qualification  \
# 0                             1                       1
# 1                             1                       1
# 2                             1                       1
# 3                             1                       1
# 4                             0                       1
#
#    Previous qualification (grade)  Nacionality  Mother's qualification  \
# 0                           122.0            1                      19
# 1                           160.0            1                       1
# ...

# %%
import os

print("Current folder:")
print(os.getcwd())

print("\nFiles/folders here:")
print(os.listdir())
# Out:
# Current folder:
# c:\Users\SAMSUNG\OneDrive\Desktop\Module-A\notebooks
#
# Files/folders here:
# ['01_eda.ipynb', '02_preprocessing.ipynb', '03_model_training.ipynb', '04_shap.ipynb']

# %%
print("Rows: ",df.shape[0])
print("columns:",df.shape[1])
# Out:
# Rows:  4424
# columns: 37

# %%
display(df.head())
# Out:
#    Marital status  Application mode  Application order  Course  \
# 0               1                17                  5     171
# 1               1                15                  1    9254
# 2               1                 1                  5    9070
# 3               1                17                  2    9773
# 4               2                39                  1    8014
#
#    Daytime/evening attendance\t  Previous qualification  \
# 0                             1                       1
# 1                             1                       1
# 2                             1                       1
# 3                             1                       1
# 4                             0                       1
#
#    Previous qualification (grade)  Nacionality  Mother's qualification  \
# 0                           122.0            1                      19
# 1                           160.0            1                       1
# ...

# %%
print(df.tail())
# Out:
#       Marital status  Application mode  Application order  Course  \
# 4419               1                 1                  6    9773
# 4420               1                 1                  2    9773
# 4421               1                 1                  1    9500
# 4422               1                 1                  1    9147
# 4423               1                10                  1    9773
#
#       Daytime/evening attendance\t  Previous qualification  \
# 4419                             1                       1
# 4420                             1                       1
# 4421                             1                       1
# 4422                             1                       1
# 4423                             1                       1
#
#       Previous qualification (grade)  Nacionality  Mother's qualification  \
# 4419                           125.0            1                       1
# ...

# %%
print("Columns in the dataset:\n")

for i, column in enumerate(df.columns, start=1):
    print(i, "→", column)
# Out:
# Columns in the dataset:
#
# 1 → Marital status
# 2 → Application mode
# 3 → Application order
# 4 → Course
# 5 → Daytime/evening attendance
# 6 → Previous qualification
# 7 → Previous qualification (grade)
# 8 → Nacionality
# 9 → Mother's qualification
# 10 → Father's qualification
# 11 → Mother's occupation
# 12 → Father's occupation
# 13 → Admission grade
# 14 → Displaced
# 15 → Educational special needs
# 16 → Debtor
# 17 → Tuition fees up to date
# 18 → Gender
# 19 → Scholarship holder
# 20 → Age at enrollment
# 21 → International
# 22 → Curricular units 1st sem (credited)
# 23 → Curricular units 1st sem (enrolled)
# 24 → Curricular units 1st sem (evaluations)
# 25 → Curricular units 1st sem (approved)
# 26 → Curricular units 1st sem (grade)
# 27 → Curricular units 1st sem (without evaluations)
# 28 → Curricular units 2nd sem (credited)
# 29 → Curricular units 2nd sem (enrolled)
# 30 → Curricular units 2nd sem (evaluations)
# 31 → Curricular units 2nd sem (approved)
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4424 entries, 0 to 4423
# Data columns (total 37 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Marital status                                  4424 non-null   int64
#  1   Application mode                                4424 non-null   int64
#  2   Application order                               4424 non-null   int64
#  3   Course                                          4424 non-null   int64
#  4   Daytime/evening attendance	                     4424 non-null   int64
#  5   Previous qualification                          4424 non-null   int64
#  6   Previous qualification (grade)                  4424 non-null   float64
#  7   Nacionality                                     4424 non-null   int64
#  8   Mother's qualification                          4424 non-null   int64
# ...

# %%
print("\nMissing values:")
print(df.isnull().sum())
# Out:
# Missing values:
# Marital status                                    0
# Application mode                                  0
# Application order                                 0
# Course                                            0
# Daytime/evening attendance\t                      0
# Previous qualification                            0
# Previous qualification (grade)                    0
# Nacionality                                       0
# Mother's qualification                            0
# Father's qualification                            0
# Mother's occupation                               0
# Father's occupation                               0
# Admission grade                                   0
# Displaced                                         0
# Educational special needs                         0
# Debtor                                            0
# Tuition fees up to date                           0
# Gender                                            0
# ...

# %%
print("Duplicate rows:", df.duplicated().sum())
# Out:
# Duplicate rows: 0

# %%
print(df["Target"].value_counts())
# Out:
# Target
# Graduate    2209
# Dropout     1421
# Enrolled     794
# Name: count, dtype: int64

# %%
print(df["Target"].value_counts(normalize=True) * 100)
# Out:
# Target
# Graduate    49.932188
# Dropout     32.120253
# Enrolled    17.947559
# Name: proportion, dtype: float64

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(7, 5))

df["Target"].value_counts().plot(kind="bar")

plt.title("Student Outcome Distribution")
plt.xlabel("Outcome")
plt.ylabel("Number of Students")
plt.xticks(rotation=0)
plt.show()

# %%
print(df.describe())
# Out:
#        Marital status  Application mode  Application order       Course  \
# count     4424.000000       4424.000000        4424.000000  4424.000000
# mean         1.178571         18.669078           1.727848  8856.642631
# std          0.605747         17.484682           1.313793  2063.566416
# min          1.000000          1.000000           0.000000    33.000000
# 25%          1.000000          1.000000           1.000000  9085.000000
# 50%          1.000000         17.000000           1.000000  9238.000000
# 75%          1.000000         39.000000           2.000000  9556.000000
# max          6.000000         57.000000           9.000000  9991.000000
#
#        Daytime/evening attendance\t  Previous qualification  \
# count                   4424.000000             4424.000000
# mean                       0.890823                4.577758
# std                        0.311897               10.216592
# min                        0.000000                1.000000
# ...

# %%
academic_columns = [
    "Curricular units 1st sem (enrolled)",
    "Curricular units 1st sem (evaluations)",
    "Curricular units 1st sem (approved)",
    "Curricular units 1st sem (grade)"
]

display(df[academic_columns].describe().T)
# Out:
#                                          count       mean       std  min  \
# Curricular units 1st sem (enrolled)     4424.0   6.270570  2.480178  0.0
# Curricular units 1st sem (evaluations)  4424.0   8.299051  4.179106  0.0
# Curricular units 1st sem (approved)     4424.0   4.706600  3.094238  0.0
# Curricular units 1st sem (grade)        4424.0  10.640822  4.843663  0.0
#
#                                          25%        50%   75%     max
# Curricular units 1st sem (enrolled)      5.0   6.000000   7.0  26.000
# Curricular units 1st sem (evaluations)   6.0   8.000000  10.0  45.000
# Curricular units 1st sem (approved)      3.0   5.000000   6.0  26.000
# Curricular units 1st sem (grade)        11.0  12.285714  13.4  18.875

# %%
import seaborn as sns
plt.figure(figsize=(8, 5))

sns.boxplot(
    data=df,
    x="Target",
    y="Curricular units 1st sem (grade)"
)

plt.title("First Semester Grade by Student Outcome")
plt.xlabel("Outcome")
plt.ylabel("First Semester Grade")
plt.show()

# %%
df.groupby("Target")["Curricular units 1st sem (grade)"].agg(
    ["count", "mean", "median", "std", "min", "max"]
)
# Out:
#           count       mean     median       std  min     max
# Target
# Dropout    1421   7.256656  10.928571  6.031120  0.0  18.000
# Enrolled    794  11.125257  12.000000  3.675084  0.0  17.000
# Graduate   2209  12.643655  13.000000  2.699027  0.0  18.875

# %%
df.groupby("Target")["Curricular units 1st sem (approved)"].mean()
# Out:
# Target
# Dropout     2.551724
# Enrolled    4.318640
# Graduate    6.232232
# Name: Curricular units 1st sem (approved), dtype: float64

# %%
df.groupby("Target")["Curricular units 1st sem (evaluations)"].mean()
# Out:
# Target
# Dropout     7.751583
# Enrolled    9.341310
# Graduate    8.276596
# Name: Curricular units 1st sem (evaluations), dtype: float64

# %%
plt.figure(figsize=(8, 5))

sns.boxplot(
    data=df,
    x="Target",
    y="Curricular units 1st sem (approved)"
)

plt.title("First Semester Approved Units by Student Outcome")
plt.xlabel("Outcome")
plt.ylabel("Approved Units")

plt.show()

# %%
print("FIRST SEMESTER GRADE")
print(
    df.groupby("Target")["Curricular units 1st sem (grade)"].mean()
)

print("\nFIRST SEMESTER APPROVED UNITS")
print(
    df.groupby("Target")["Curricular units 1st sem (approved)"].mean()
)
# Out:
# FIRST SEMESTER GRADE
# Target
# Dropout      7.256656
# Enrolled    11.125257
# Graduate    12.643655
# Name: Curricular units 1st sem (grade), dtype: float64
#
# FIRST SEMESTER APPROVED UNITS
# Target
# Dropout     2.551724
# Enrolled    4.318640
# Graduate    6.232232
# Name: Curricular units 1st sem (approved), dtype: float64

# %%
print("\nFIRST SEMESTER EVALUATIONS")
print(
    df.groupby("Target")["Curricular units 1st sem (evaluations)"].mean()
)
# Out:
# FIRST SEMESTER EVALUATIONS
# Target
# Dropout     7.751583
# Enrolled    9.341310
# Graduate    8.276596
# Name: Curricular units 1st sem (evaluations), dtype: float64
